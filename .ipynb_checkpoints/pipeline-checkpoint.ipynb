# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Split the dataset for train and test

# %%
X_full = pd.read_csv('home-data-for-ml-course/train.csv', index_col='Id')
X_test_full = pd.read_csv('home-data-for-ml-course/test.csv', index_col='Id')

# %% [markdown]
# ### Check if there is null in the target set

# %%
X_full.shape
# Out:
# (1460, 80)

# %%
X_full[X_full['SalePrice'].isnull()]
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 80 columns]

# %%
X_full.dropna(axis=0, subset=['SalePrice'], inplace=True)

# %%
X_full.head(10)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
# 6           50       RL         85.0    14115   Pave   NaN      IR1
# 7           20       RL         75.0    10084   Pave   NaN      Reg
# 8           60       RL          NaN    10382   Pave   NaN      IR1
# 9           50       RM         51.0     6120   Pave   NaN      Reg
# 10         190       RL         50.0     7420   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig    ...     PoolArea PoolQC  Fence  \
# Id                                    ...
# 1          Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2          Lvl    AllPub       FR2    ...            0    NaN    NaN
# 3          Lvl    AllPub    Inside    ...            0    NaN    NaN
# 4          Lvl    AllPub    Corner    ...            0    NaN    NaN
# 5          Lvl    AllPub       FR2    ...            0    NaN    NaN
# 6          Lvl    AllPub    Inside    ...            0    NaN  MnPrv
# 7          Lvl    AllPub    Inside    ...            0    NaN    NaN
# 8          Lvl    AllPub    Corner    ...            0    NaN    NaN
# 9          Lvl    AllPub    Inside    ...            0    NaN    NaN
# 10         Lvl    AllPub    Corner    ...            0    NaN    NaN
#
#    MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          NaN       0      2    2008        WD         Normal     208500
# 2          NaN       0      5    2007        WD         Normal     181500
# 3          NaN       0      9    2008        WD         Normal     223500
# 4          NaN       0      2    2006        WD        Abnorml     140000
# 5          NaN       0     12    2008        WD         Normal     250000
# 6         Shed     700     10    2009        WD         Normal     143000
# 7          NaN       0      8    2007        WD         Normal     307000
# 8         Shed     350     11    2009        WD         Normal     200000
# 9          NaN       0      4    2008        WD        Abnorml     129900
# 10         NaN       0      1    2008        WD         Normal     118000
#
# [10 rows x 80 columns]

# %%
X = X_full.drop(['SalePrice'], axis=1)
y = X_full['SalePrice']

# %% [markdown]
# ### Split the dataset

# %%
X_train, X_pred, y_train, y_pred = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
### Divide the dataset into categorical and numerical set

# %%
### Select these categorical columns with relatively low number of unique values

# %%
categorical_cols = [cname for cname in X_train.columns if X_train[cname].nunique()<10 
                    and X_train[cname].dtype=='object']

# %%
numerical_cols = [nname for nname in X_train.columns if X_train[nname].dtype in ['int64', 'float64']]

# %%
### Handling missing values and Convert categorical data to numerical data

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from skleran.preprocessing import OneHotEncoder

# %%
categorical_transformers = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='most_frequent')
        ('onehot', OneHotEncoder(handle_unknown='ignore')))
    ])

# %%
### Processing numerical missing values

# %%
numerical_transformers = SimpleImputer(strategy='constant')

# %%
### Bundle preprocessing for both num and cat

# %%
from sklearn.compose import ColumnTransformer

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols),
    ]
)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Label_X_train = X_train[categorical_cols]

# %%
label_encoder = LabelEncoder()

# %%
for col in categorical_cols:
# Out:
# Id
# 255     3
# 1067    3
# 639     3
# 800     3
# 381     3
# 304     3
# 87      3
# 1386    4
# 266     3
# 794     3
# 1446    3
# 809     3
# 1100    3
# 606     3
# 702     3
# 222     3
# 114     3
# 549     4
# 1074    3
# 175     3
# 515     3
# 1351    3
# 1146    4
# 966     3
# 937     3
# 286     1
# 1311    3
# 343     3
# 1166    3
# 32      3
#        ..
# 748     4
# 253     3
# 22      4
# 1338    4
# 460     3
# 1185    3
# 277     3
# 956     2
# 1216    3
# 386     3
# 806     3
# 1438    3
# 344     3
# 770     3
# 1333    3
# 131     3
# 872     3
# 1124    3
# 1397    3
# 88      1
# 331     3
# 1239    3
# 467     3
# 122     4
# 1045    3
# 1096    3
# 1131    3
# 1295    3
# 861     3
# 1127    3
# Name: MSZoning, Length: 1168, dtype: int64
# Id
# 255     1
# 1067    1
# 639     1
# 800     1
# 381     1
# 304     1
# 87      1
# 1386    1
# 266     1
# 794     1
# 1446    1
# 809     1
# 1100    1
# 606     1
# 702     1
# 222     1
# 114     1
# 549     1
# 1074    1
# 175     1
# 515     1
# 1351    1
# 1146    1
# 966     1
# 937     1
# 286     1
# 1311    1
# 343     1
# 1166    1
# 32      1
#        ..
# 748     1
# 253     1
# 22      1
# 1338    1
# 460     1
# 1185    0
# 277     1
# 956     1
# 1216    1
# 386     1
# 806     1
# 1438    1
# 344     1
# 770     1
# 1333    1
# 131     1
# 872     1
# 1124    1
# 1397    1
# 88      1
# 331     1
# 1239    1
# 467     1
# 122     1
# 1045    1
# 1096    1
# 1131    1
# 1295    1
# 861     1
# 1127    1
# Name: Street, Length: 1168, dtype: int64
# Id
# 255      NaN
# 1067     NaN
# 639      NaN
# 800      NaN
# 381     Pave
# 304      NaN
# 87       NaN
# 1386     NaN
# 266      NaN
# 794      NaN
# 1446     NaN
# 809      NaN
# 1100     NaN
# 606      NaN
# 702      NaN
# 222      NaN
# 114      NaN
# 549      NaN
# 1074     NaN
# 175      NaN
# 515      NaN
# 1351     NaN
# 1146     NaN
# 966      NaN
# 937      NaN
# 286     Pave
# 1311     NaN
# 343      NaN
# 1166     NaN
# 32       NaN
#         ...
# 748     Pave
# 253      NaN
# 22      Grvl
# 1338    Grvl
# 460      NaN
# 1185     NaN
# 277      NaN
# 956      NaN
# 1216     NaN
# 386      NaN
# 806      NaN
# 1438     NaN
# 344      NaN
# 770      NaN
# 1333     NaN
# 131      NaN
# 872      NaN
# 1124     NaN
# 1397     NaN
# 88      Pave
# 331      NaN
# 1239     NaN
# 467      NaN
# 122      NaN
# 1045     NaN
# 1096     NaN
# 1131     NaN
# 1295     NaN
# 861      NaN
# 1127     NaN
# Name: Alley, Length: 1168, dtype: object
# Id
# 255     Reg
# 1067    IR1
# 639     Reg
# 800     Reg
# 381     Reg
# 304     Reg
# 87      IR2
# 1386    Reg
# 266     IR1
# 794     Reg
# 1446    Reg
# 809     Reg
# 1100    IR1
# 606     Reg
# 702     Reg
# 222     IR1
# 114     Reg
# 549     IR1
# 1074    IR1
# 175     IR1
# 515     Reg
# 1351    Reg
# 1146    Reg
# 966     Reg
# 937     Reg
# 286     IR1
# 1311    Reg
# 343     Reg
# 1166    IR1
# 32      IR1
#        ...
# 748     IR1
# 253     IR1
# 22      Reg
# 1338    IR1
# 460     IR1
# 1185    Reg
# 277     IR1
# 956     IR1
# 1216    IR1
# 386     Reg
# 806     IR1
# 1438    Reg
# 344     IR1
# 770     IR2
# 1333    Reg
# 131     Reg
# 872     Reg
# 1124    Reg
# 1397    IR1
# 88      Reg
# 331     IR1
# 1239    Reg
# 467     Reg
# 122     Reg
# 1045    Reg
# 1096    IR1
# 1131    Reg
# 1295    Reg
# 861     Reg
# 1127    Reg
# Name: LotShape, Length: 1168, dtype: object
# Id
# 255     Lvl
# 1067    Lvl
# 639     Lvl
# 800     Lvl
# 381     Lvl
# 304     Lvl
# 87      Lvl
# 1386    Lvl
# 266     Lvl
# 794     Lvl
# 1446    Lvl
# 809     Lvl
# 1100    Lvl
# 606     Lvl
# 702     Lvl
# 222     Lvl
# 114     Bnk
# 549     HLS
# 1074    Bnk
# 175     Lvl
# 515     Lvl
# 1351    Lvl
# 1146    Lvl
# 966     Lvl
# 937     Lvl
# 286     Lvl
# 1311    Lvl
# 343     Lvl
# 1166    Lvl
# 32      Lvl
#        ...
# 748     Lvl
# 253     Lvl
# 22      Bnk
# 1338    Bnk
# 460     Bnk
# 1185    Lvl
# 277     Lvl
# 956     HLS
# 1216    Lvl
# 386     Lvl
# 806     Lvl
# 1438    Lvl
# 344     Lvl
# 770     HLS
# 1333    Lvl
# 131     Lvl
# 872     Lvl
# 1124    Lvl
# 1397    Bnk
# 88      Lvl
# 331     Lvl
# 1239    Lvl
# 467     Lvl
# 122     Lvl
# 1045    Lvl
# 1096    Lvl
# 1131    Lvl
# 1295    Lvl
# 861     Lvl
# 1127    Lvl
# Name: LandContour, Length: 1168, dtype: object
# Id
# 255     AllPub
# 1067    AllPub
# 639     AllPub
# 800     AllPub
# 381     AllPub
# 304     AllPub
# 87      AllPub
# 1386    AllPub
# 266     AllPub
# 794     AllPub
# 1446    AllPub
# 809     AllPub
# 1100    AllPub
# 606     AllPub
# 702     AllPub
# 222     AllPub
# 114     AllPub
# 549     AllPub
# 1074    AllPub
# 175     AllPub
# 515     AllPub
# 1351    AllPub
# 1146    AllPub
# 966     AllPub
# 937     AllPub
# 286     AllPub
# 1311    AllPub
# 343     AllPub
# 1166    AllPub
# 32      AllPub
#          ...
# 748     AllPub
# 253     AllPub
# 22      AllPub
# 1338    AllPub
# 460     AllPub
# 1185    AllPub
# 277     AllPub
# 956     AllPub
# 1216    AllPub
# 386     AllPub
# 806     AllPub
# 1438    AllPub
# 344     AllPub
# 770     AllPub
# 1333    AllPub
# 131     AllPub
# 872     AllPub
# 1124    AllPub
# 1397    AllPub
# 88      AllPub
# 331     AllPub
# 1239    AllPub
# 467     AllPub
# 122     AllPub
# 1045    AllPub
# 1096    AllPub
# 1131    AllPub
# 1295    AllPub
# 861     AllPub
# 1127    AllPub
# Name: Utilities, Length: 1168, dtype: object
# Id
# 255      Inside
# 1067     Inside
# 639      Inside
# 800      Corner
# 381      Inside
# 304      Corner
# 87       Inside
# 1386     Inside
# 266      Inside
# 794      Inside
# 1446     Inside
# 809      Inside
# 1100     Inside
# 606      Inside
# 702      Inside
# 222      Inside
# 114      Corner
# 549      Inside
# 1074     Corner
# 175      Inside
# 515      Inside
# 1351     Inside
# 1146     Inside
# 966      Inside
# 937      Inside
# 286      Inside
# 1311     Inside
# 343      Inside
# 1166     Inside
# 32      CulDSac
#          ...
# 748      Corner
# 253      Inside
# 22       Inside
# 1338     Corner
# 460      Corner
# 1185     Inside
# 277      Inside
# 956      Inside
# 1216     Inside
# 386      Inside
# 806         FR2
# 1438        FR2
# 344      Inside
# 770     CulDSac
# 1333     Inside
# 131      Corner
# 872      Inside
# 1124     Inside
# 1397     Inside
# 88       Corner
# 331      Inside
# 1239     Inside
# 467      Inside
# 122      Inside
# 1045     Inside
# 1096     Inside
# 1131     Inside
# 1295     Inside
# 861      Corner
# 1127     Inside
# Name: LotConfig, Length: 1168, dtype: object
# Id
# 255     Gtl
# 1067    Gtl
# 639     Gtl
# 800     Gtl
# 381     Gtl
# 304     Gtl
# 87      Gtl
# 1386    Gtl
# 266     Gtl
# 794     Gtl
# 1446    Gtl
# 809     Gtl
# 1100    Gtl
# 606     Gtl
# 702     Gtl
# 222     Gtl
# 114     Gtl
# 549     Gtl
# 1074    Gtl
# 175     Gtl
# 515     Gtl
# 1351    Gtl
# 1146    Gtl
# 966     Gtl
# 937     Gtl
# 286     Gtl
# 1311    Gtl
# 343     Gtl
# 1166    Gtl
# 32      Gtl
#        ...
# 748     Gtl
# 253     Gtl
# 22      Gtl
# 1338    Mod
# 460     Gtl
# 1185    Mod
# 277     Gtl
# 956     Gtl
# 1216    Gtl
# 386     Gtl
# 806     Gtl
# 1438    Gtl
# 344     Gtl
# 770     Mod
# 1333    Mod
# 131     Gtl
# 872     Gtl
# 1124    Gtl
# 1397    Sev
# 88      Gtl
# 331     Gtl
# 1239    Gtl
# 467     Gtl
# 122     Gtl
# 1045    Gtl
# 1096    Gtl
# 1131    Gtl
# 1295    Gtl
# 861     Gtl
# 1127    Gtl
# Name: LandSlope, Length: 1168, dtype: object
# Id
# 255       Norm
# 1067      Norm
# 639      Feedr
# 800      Feedr
# 381       Norm
# 304       Norm
# 87        Norm
# 1386      Norm
# 266       Norm
# 794       Norm
# 1446      Norm
# 809       Norm
# 1100      RRAn
# 606       Norm
# 702       Norm
# 222       Norm
# 114       Norm
# 549      Feedr
# 1074      Norm
# 175       Norm
# 515       Norm
# 1351    Artery
# 1146      Norm
# 966       RRAn
# 937       Norm
# 286       Norm
# 1311      PosA
# 343       Norm
# 1166      Norm
# 32        Norm
#          ...
# 748       Norm
# 253       Norm
# 22        Norm
# 1338     Feedr
# 460       Norm
# 1185      Norm
# 277       Norm
# 956       Norm
# 1216      Norm
# 386       Norm
# 806       Norm
# 1438      Norm
# 344       Norm
# 770       Norm
# 1333      Norm
# 131       Norm
# 872       Norm
# 1124      Norm
# 1397      Norm
# 88        Norm
# 331       Norm
# 1239      RRAe
# 467       Norm
# 122       Norm
# 1045      PosN
# 1096      Norm
# 1131      Norm
# 1295      Norm
# 861       Norm
# 1127      Norm
# Name: Condition1, Length: 1168, dtype: object
# Id
# 255     Norm
# 1067    Norm
# 639     Norm
# 800     Norm
# 381     Norm
# 304     Norm
# 87      Norm
# 1386    Norm
# 266     Norm
# 794     Norm
# 1446    Norm
# 809     Norm
# 1100    Norm
# 606     Norm
# 702     Norm
# 222     Norm
# 114     Norm
# 549     RRNn
# 1074    Norm
# 175     Norm
# 515     Norm
# 1351    Norm
# 1146    Norm
# 966     Norm
# 937     Norm
# 286     Norm
# 1311    Norm
# 343     Norm
# 1166    Norm
# 32      Norm
#         ...
# 748     Norm
# 253     Norm
# 22      Norm
# 1338    Norm
# 460     Norm
# 1185    Norm
# 277     Norm
# 956     Norm
# 1216    Norm
# 386     Norm
# 806     Norm
# 1438    Norm
# 344     Norm
# 770     Norm
# 1333    Norm
# 131     Norm
# 872     Norm
# 1124    Norm
# 1397    Norm
# 88      Norm
# 331     Norm
# 1239    Norm
# 467     Norm
# 122     Norm
# 1045    Norm
# 1096    Norm
# 1131    Norm
# 1295    Norm
# 861     Norm
# 1127    Norm
# Name: Condition2, Length: 1168, dtype: object
# Id
# 255       1Fam
# 1067      1Fam
# 639       1Fam
# 800       1Fam
# 381       1Fam
# 304       1Fam
# 87        1Fam
# 1386      1Fam
# 266       1Fam
# 794       1Fam
# 1446      1Fam
# 809       1Fam
# 1100      1Fam
# 606       1Fam
# 702       1Fam
# 222       1Fam
# 114       1Fam
# 549       1Fam
# 1074      1Fam
# 175       1Fam
# 515       1Fam
# 1351    Duplex
# 1146      1Fam
# 966       1Fam
# 937       1Fam
# 286     TwnhsE
# 1311      1Fam
# 343     Duplex
# 1166      1Fam
# 32        1Fam
#          ...
# 748       1Fam
# 253       1Fam
# 22        1Fam
# 1338      1Fam
# 460       1Fam
# 1185      1Fam
# 277       1Fam
# 956     Duplex
# 1216      1Fam
# 386     TwnhsE
# 806       1Fam
# 1438      1Fam
# 344     TwnhsE
# 770       1Fam
# 1333      1Fam
# 131       1Fam
# 872       1Fam
# 1124      1Fam
# 1397      1Fam
# 88      TwnhsE
# 331     Duplex
# 1239      1Fam
# 467       1Fam
# 122       1Fam
# 1045      1Fam
# 1096      1Fam
# 1131      1Fam
# 1295      1Fam
# 861       1Fam
# 1127    TwnhsE
# Name: BldgType, Length: 1168, dtype: object
# Id
# 255     1Story
# 1067    2Story
# 639     1Story
# 800     1.5Fin
# 381     1.5Fin
# 304     1Story
# 87      2Story
# 1386    1.5Fin
# 266     1Story
# 794     1Story
# 1446    SFoyer
# 809       SLvl
# 1100    1Story
# 606     2Story
# 702     1Story
# 222     2Story
# 114     1Story
# 549     1Story
# 1074    2Story
# 175     1Story
# 515     1.5Unf
# 1351    2Story
# 1146    1.5Fin
# 966     2Story
# 937     1Story
# 286     2Story
# 1311    1Story
# 343     1Story
# 1166    1Story
# 32      1Story
#          ...
# 748     2Story
# 253     2Story
# 22      1.5Unf
# 1338    1Story
# 460     1.5Fin
# 1185    1Story
# 277     1Story
# 956     2Story
# 1216    1Story
# 386     1Story
# 806     1Story
# 1438    1Story
# 344     1Story
# 770     2Story
# 1333    1Story
# 131     2Story
# 872     2Story
# 1124    1Story
# 1397    1Story
# 88      2Story
# 331     1Story
# 1239    1Story
# 467     1Story
# 122     1.5Fin
# 1045    1Story
# 1096    1Story
# 1131    1.5Fin
# 1295    1Story
# 861     1.5Fin
# 1127    1Story
# Name: HouseStyle, Length: 1168, dtype: object
# Id
# 255       Gable
# 1067      Gable
# 639       Gable
# 800       Gable
# 381       Gable
# 304       Gable
# 87        Gable
# 1386      Gable
# 266       Gable
# 794       Gable
# 1446      Gable
# 809       Gable
# 1100      Gable
# 606       Gable
# 702         Hip
# 222       Gable
# 114         Hip
# 549       Gable
# 1074        Hip
# 175       Gable
# 515       Gable
# 1351      Gable
# 1146      Gable
# 966       Gable
# 937       Gable
# 286       Gable
# 1311      Gable
# 343       Gable
# 1166      Gable
# 32        Gable
#          ...
# 748     Mansard
# 253       Gable
# 22        Gable
# 1338      Gable
# 460       Gable
# 1185        Hip
# 277       Gable
# 956       Gable
# 1216      Gable
# 386       Gable
# 806       Gable
# 1438        Hip
# 344         Hip
# 770         Hip
# 1333      Gable
# 131       Gable
# 872       Gable
# 1124        Hip
# 1397      Gable
# 88        Gable
# 331       Gable
# 1239      Gable
# 467        Flat
# 122       Gable
# 1045        Hip
# 1096      Gable
# 1131      Gable
# 1295        Hip
# 861       Gable
# 1127        Hip
# Name: RoofStyle, Length: 1168, dtype: object
# Id
# 255     CompShg
# 1067    CompShg
# 639     CompShg
# 800     CompShg
# 381     CompShg
# 304     CompShg
# 87      CompShg
# 1386    CompShg
# 266     CompShg
# 794     CompShg
# 1446    CompShg
# 809     CompShg
# 1100    CompShg
# 606     CompShg
# 702     CompShg
# 222     CompShg
# 114     CompShg
# 549     CompShg
# 1074    CompShg
# 175     CompShg
# 515     CompShg
# 1351    CompShg
# 1146    CompShg
# 966     CompShg
# 937     CompShg
# 286     CompShg
# 1311    CompShg
# 343     CompShg
# 1166    CompShg
# 32      CompShg
#          ...
# 748     CompShg
# 253     CompShg
# 22      CompShg
# 1338    CompShg
# 460     CompShg
# 1185    CompShg
# 277     CompShg
# 956     CompShg
# 1216    CompShg
# 386     CompShg
# 806     CompShg
# 1438    CompShg
# 344     CompShg
# 770     CompShg
# 1333    CompShg
# 131     CompShg
# 872     CompShg
# 1124    CompShg
# 1397    CompShg
# 88      CompShg
# 331     CompShg
# 1239    CompShg
# 467     Tar&Grv
# 122     CompShg
# 1045    WdShngl
# 1096    CompShg
# 1131    CompShg
# 1295    CompShg
# 861     CompShg
# 1127    CompShg
# Name: RoofMatl, Length: 1168, dtype: object
# Id
# 255        None
# 1067       None
# 639        None
# 800     BrkFace
# 381        None
# 304        None
# 87         None
# 1386       None
# 266     BrkFace
# 794       Stone
# 1446       None
# 809     BrkFace
# 1100    BrkFace
# 606     BrkFace
# 702     BrkFace
# 222        None
# 114     BrkFace
# 549        None
# 1074    BrkFace
# 175       Stone
# 515        None
# 1351    BrkFace
# 1146       None
# 966        None
# 937         NaN
# 286        None
# 1311       None
# 343     BrkFace
# 1166      Stone
# 32         None
#          ...
# 748        None
# 253        None
# 22         None
# 1338       None
# 460      BrkCmn
# 1185    BrkFace
# 277        None
# 956     BrkFace
# 1216       None
# 386     BrkFace
# 806       Stone
# 1438      Stone
# 344     BrkFace
# 770     BrkFace
# 1333       None
# 131     BrkFace
# 872     BrkFace
# 1124       None
# 1397       None
# 88        Stone
# 331     BrkFace
# 1239       None
# 467        None
# 122        None
# 1045       None
# 1096       None
# 1131       None
# 1295       None
# 861        None
# 1127    BrkFace
# Name: MasVnrType, Length: 1168, dtype: object
# Id
# 255     TA
# 1067    Gd
# 639     TA
# 800     TA
# 381     TA
# 304     TA
# 87      Gd
# 1386    TA
# 266     TA
# 794     Gd
# 1446    TA
# 809     TA
# 1100    TA
# 606     TA
# 702     TA
# 222     Gd
# 114     TA
# 549     TA
# 1074    TA
# 175     TA
# 515     TA
# 1351    TA
# 1146    TA
# 966     Gd
# 937     Gd
# 286     Gd
# 1311    Gd
# 343     TA
# 1166    Gd
# 32      TA
#         ..
# 748     Gd
# 253     Gd
# 22      TA
# 1338    TA
# 460     TA
# 1185    TA
# 277     Gd
# 956     TA
# 1216    TA
# 386     Gd
# 806     Gd
# 1438    Ex
# 344     Ex
# 770     Ex
# 1333    TA
# 131     TA
# 872     TA
# 1124    TA
# 1397    TA
# 88      Gd
# 331     TA
# 1239    Gd
# 467     TA
# 122     TA
# 1045    Gd
# 1096    Gd
# 1131    TA
# 1295    TA
# 861     Gd
# 1127    Gd
# Name: ExterQual, Length: 1168, dtype: object
# Id
# 255     Gd
# 1067    TA
# 639     TA
# 800     TA
# 381     TA
# 304     TA
# 87      TA
# 1386    Gd
# 266     Gd
# 794     TA
# 1446    TA
# 809     TA
# 1100    TA
# 606     TA
# 702     TA
# 222     TA
# 114     Gd
# 549     Gd
# 1074    TA
# 175     TA
# 515     TA
# 1351    TA
# 1146    TA
# 966     TA
# 937     TA
# 286     TA
# 1311    Gd
# 343     TA
# 1166    TA
# 32      TA
#         ..
# 748     TA
# 253     TA
# 22      TA
# 1338    TA
# 460     TA
# 1185    TA
# 277     TA
# 956     TA
# 1216    TA
# 386     TA
# 806     TA
# 1438    TA
# 344     TA
# 770     TA
# 1333    TA
# 131     TA
# 872     TA
# 1124    Ex
# 1397    TA
# 88      TA
# 331     TA
# 1239    TA
# 467     Gd
# 122     TA
# 1045    TA
# 1096    TA
# 1131    TA
# 1295    TA
# 861     TA
# 1127    TA
# Name: ExterCond, Length: 1168, dtype: object
# Id
# 255     CBlock
# 1067     PConc
# 639     CBlock
# 800     BrkTil
# 381     BrkTil
# 304      PConc
# 87       PConc
# 1386    BrkTil
# 266     CBlock
# 794      PConc
# 1446    CBlock
# 809     CBlock
# 1100    CBlock
# 606     CBlock
# 702     CBlock
# 222      PConc
# 114     CBlock
# 549     CBlock
# 1074    CBlock
# 175     CBlock
# 515     BrkTil
# 1351    CBlock
# 1146    BrkTil
# 966      PConc
# 937      PConc
# 286      PConc
# 1311     PConc
# 343       Slab
# 1166     PConc
# 32      CBlock
#          ...
# 748      Stone
# 253      PConc
# 22       PConc
# 1338    CBlock
# 460     CBlock
# 1185    CBlock
# 277      PConc
# 956     CBlock
# 1216    CBlock
# 386      PConc
# 806      PConc
# 1438     PConc
# 344      PConc
# 770      PConc
# 1333    CBlock
# 131     CBlock
# 872      PConc
# 1124    CBlock
# 1397    CBlock
# 88       PConc
# 331     CBlock
# 1239     PConc
# 467     CBlock
# 122      PConc
# 1045     PConc
# 1096     PConc
# 1131    BrkTil
# 1295    CBlock
# 861     BrkTil
# 1127     PConc
# Name: Foundation, Length: 1168, dtype: object
# Id
# 255      TA
# 1067     Gd
# 639      Fa
# 800      Gd
# 381      TA
# 304      TA
# 87       Gd
# 1386     TA
# 266      Gd
# 794      Gd
# 1446     TA
# 809      TA
# 1100     Gd
# 606      TA
# 702      TA
# 222      Gd
# 114      Gd
# 549      TA
# 1074     TA
# 175      Gd
# 515      TA
# 1351     TA
# 1146     TA
# 966      Gd
# 937      Gd
# 286      Gd
# 1311     Gd
# 343     NaN
# 1166     Gd
# 32       TA
#        ...
# 748      TA
# 253      Gd
# 22       TA
# 1338     TA
# 460      TA
# 1185     TA
# 277      Ex
# 956      Gd
# 1216     TA
# 386      Gd
# 806      Gd
# 1438     Ex
# 344      Ex
# 770      Gd
# 1333     TA
# 131      TA
# 872      Gd
# 1124     TA
# 1397     TA
# 88       Gd
# 331      TA
# 1239     Gd
# 467      TA
# 122      TA
# 1045     Gd
# 1096     Gd
# 1131     TA
# 1295     TA
# 861      TA
# 1127     Gd
# Name: BsmtQual, Length: 1168, dtype: object
# Id
# 255      TA
# 1067     TA
# 639      TA
# 800      TA
# 381      TA
# 304      TA
# 87       TA
# 1386     TA
# 266      TA
# 794      TA
# 1446     TA
# 809      TA
# 1100     TA
# 606      TA
# 702      TA
# 222      TA
# 114      TA
# 549      TA
# 1074     TA
# 175      Fa
# 515      TA
# 1351     TA
# 1146     TA
# 966      TA
# 937      TA
# 286      TA
# 1311     TA
# 343     NaN
# 1166     TA
# 32       TA
#        ...
# 748      Fa
# 253      TA
# 22       TA
# 1338     TA
# 460      TA
# 1185     TA
# 277      TA
# 956      TA
# 1216     TA
# 386      TA
# 806      TA
# 1438     TA
# 344      TA
# 770      TA
# 1333     TA
# 131      TA
# 872      TA
# 1124     TA
# 1397     TA
# 88       TA
# 331      TA
# 1239     TA
# 467      Gd
# 122      TA
# 1045     TA
# 1096     TA
# 1131     TA
# 1295     TA
# 861      TA
# 1127     TA
# Name: BsmtCond, Length: 1168, dtype: object
# Id
# 255      No
# 1067     No
# 639      No
# 800      No
# 381      No
# 304      No
# 87       Av
# 1386     No
# 266      No
# 794      Av
# 1446     Gd
# 809      Av
# 1100     No
# 606      No
# 702      No
# 222      No
# 114      Mn
# 549      No
# 1074     No
# 175      No
# 515      No
# 1351     No
# 1146     No
# 966      No
# 937      No
# 286      No
# 1311     Av
# 343     NaN
# 1166     No
# 32       No
#        ...
# 748      No
# 253      No
# 22       No
# 1338     No
# 460      No
# 1185     Gd
# 277      No
# 956      No
# 1216     No
# 386      No
# 806      No
# 1438     Av
# 344      No
# 770      Gd
# 1333     Mn
# 131      No
# 872      No
# 1124     No
# 1397     Av
# 88       Av
# 331      No
# 1239     No
# 467      Gd
# 122      No
# 1045     No
# 1096     No
# 1131     No
# 1295     No
# 861      No
# 1127     No
# Name: BsmtExposure, Length: 1168, dtype: object
# Id
# 255     Rec
# 1067    Unf
# 639     Unf
# 800     ALQ
# 381     LwQ
# 304     ALQ
# 87      Unf
# 1386    BLQ
# 266     GLQ
# 794     Unf
# 1446    LwQ
# 809     ALQ
# 1100    ALQ
# 606     BLQ
# 702     Unf
# 222     Unf
# 114     ALQ
# 549     LwQ
# 1074    BLQ
# 175     ALQ
# 515     Unf
# 1351    LwQ
# 1146    Unf
# 966     Unf
# 937     GLQ
# 286     Unf
# 1311    GLQ
# 343     NaN
# 1166    Unf
# 32      Unf
#        ...
# 748     Unf
# 253     Unf
# 22      Unf
# 1338    Unf
# 460     LwQ
# 1185    Rec
# 277     Unf
# 956     Rec
# 1216    Rec
# 386     GLQ
# 806     Unf
# 1438    GLQ
# 344     GLQ
# 770     ALQ
# 1333    ALQ
# 131     Rec
# 872     GLQ
# 1124    Unf
# 1397    BLQ
# 88      Unf
# 331     GLQ
# 1239    Unf
# 467     GLQ
# 122     Unf
# 1045    ALQ
# 1096    GLQ
# 1131    BLQ
# 1295    Rec
# 861     Unf
# 1127    Unf
# Name: BsmtFinType1, Length: 1168, dtype: object
# Id
# 255     Unf
# 1067    Unf
# 639     Unf
# 800     Unf
# 381     Unf
# 304     Unf
# 87      Unf
# 1386    Unf
# 266     LwQ
# 794     Unf
# 1446    Rec
# 809     BLQ
# 1100    Unf
# 606     Unf
# 702     Unf
# 222     Unf
# 114     Rec
# 549     Rec
# 1074    Unf
# 175     LwQ
# 515     Unf
# 1351    Unf
# 1146    Unf
# 966     Unf
# 937     Unf
# 286     Unf
# 1311    Unf
# 343     NaN
# 1166    Unf
# 32      Unf
#        ...
# 748     Unf
# 253     Unf
# 22      Unf
# 1338    Unf
# 460     Unf
# 1185    Unf
# 277     Unf
# 956     Unf
# 1216    LwQ
# 386     Unf
# 806     Unf
# 1438    Unf
# 344     Unf
# 770     Unf
# 1333    Unf
# 131     Unf
# 872     Unf
# 1124    Unf
# 1397    Rec
# 88      Unf
# 331     Rec
# 1239    Unf
# 467     Unf
# 122     Unf
# 1045    Unf
# 1096    Unf
# 1131    Unf
# 1295    Unf
# 861     Unf
# 1127    Unf
# Name: BsmtFinType2, Length: 1168, dtype: object
# Id
# 255     GasA
# 1067    GasA
# 639     GasA
# 800     GasA
# 381     GasA
# 304     GasA
# 87      GasA
# 1386    GasA
# 266     GasA
# 794     GasA
# 1446    GasA
# 809     GasA
# 1100    GasA
# 606     GasA
# 702     GasA
# 222     GasA
# 114     GasA
# 549     GasA
# 1074    GasA
# 175     GasA
# 515     Grav
# 1351    GasA
# 1146    GasA
# 966     GasA
# 937     GasA
# 286     GasA
# 1311    GasA
# 343     Wall
# 1166    GasA
# 32      GasA
#         ...
# 748     GasW
# 253     GasA
# 22      GasA
# 1338    Grav
# 460     GasA
# 1185    GasA
# 277     GasA
# 956     GasA
# 1216    GasA
# 386     GasA
# 806     GasA
# 1438    GasA
# 344     GasA
# 770     GasA
# 1333    GasA
# 131     GasA
# 872     GasA
# 1124    GasA
# 1397    GasA
# 88      GasA
# 331     GasA
# 1239    GasA
# 467     GasA
# 122     GasA
# 1045    GasA
# 1096    GasA
# 1131    GasA
# 1295    GasA
# 861     GasA
# 1127    GasA
# Name: Heating, Length: 1168, dtype: object
# Id
# 255     TA
# 1067    Gd
# 639     Gd
# 800     Ex
# 381     TA
# 304     TA
# 87      Ex
# 1386    Gd
# 266     TA
# 794     Ex
# 1446    Gd
# 809     TA
# 1100    TA
# 606     TA
# 702     TA
# 222     Ex
# 114     TA
# 549     TA
# 1074    TA
# 175     TA
# 515     Fa
# 1351    TA
# 1146    Ex
# 966     Ex
# 937     Ex
# 286     Ex
# 1311    TA
# 343     Fa
# 1166    Ex
# 32      Gd
#         ..
# 748     TA
# 253     Ex
# 22      Ex
# 1338    Fa
# 460     TA
# 1185    Gd
# 277     Ex
# 956     TA
# 1216    TA
# 386     Ex
# 806     Ex
# 1438    Ex
# 344     Ex
# 770     Ex
# 1333    Ex
# 131     Ex
# 872     Ex
# 1124    Ex
# 1397    TA
# 88      Ex
# 331     TA
# 1239    Ex
# 467     TA
# 122     Gd
# 1045    TA
# 1096    Gd
# 1131    TA
# 1295    TA
# 861     Gd
# 1127    Ex
# Name: HeatingQC, Length: 1168, dtype: object
# Id
# 255     Y
# 1067    Y
# 639     Y
# 800     Y
# 381     Y
# 304     Y
# 87      Y
# 1386    Y
# 266     Y
# 794     Y
# 1446    Y
# 809     Y
# 1100    Y
# 606     Y
# 702     Y
# 222     Y
# 114     Y
# 549     Y
# 1074    Y
# 175     Y
# 515     N
# 1351    Y
# 1146    Y
# 966     Y
# 937     Y
# 286     Y
# 1311    Y
# 343     N
# 1166    Y
# 32      Y
#        ..
# 748     N
# 253     Y
# 22      Y
# 1338    N
# 460     Y
# 1185    Y
# 277     Y
# 956     N
# 1216    Y
# 386     Y
# 806     Y
# 1438    Y
# 344     Y
# 770     Y
# 1333    Y
# 131     Y
# 872     Y
# 1124    Y
# 1397    Y
# 88      Y
# 331     Y
# 1239    Y
# 467     Y
# 122     Y
# 1045    Y
# 1096    Y
# 1131    Y
# 1295    Y
# 861     Y
# 1127    Y
# Name: CentralAir, Length: 1168, dtype: object
# Id
# 255     SBrkr
# 1067    SBrkr
# 639     FuseA
# 800     SBrkr
# 381     SBrkr
# 304     SBrkr
# 87      SBrkr
# 1386    SBrkr
# 266     SBrkr
# 794     SBrkr
# 1446    SBrkr
# 809     SBrkr
# 1100    SBrkr
# 606     SBrkr
# 702     SBrkr
# 222     SBrkr
# 114     SBrkr
# 549     SBrkr
# 1074    SBrkr
# 175     SBrkr
# 515     SBrkr
# 1351    SBrkr
# 1146    SBrkr
# 966     SBrkr
# 937     SBrkr
# 286     SBrkr
# 1311    SBrkr
# 343     FuseA
# 1166    SBrkr
# 32      SBrkr
#         ...
# 748     SBrkr
# 253     SBrkr
# 22      FuseF
# 1338    FuseA
# 460     SBrkr
# 1185    SBrkr
# 277     SBrkr
# 956     FuseF
# 1216    SBrkr
# 386     SBrkr
# 806     SBrkr
# 1438    SBrkr
# 344     SBrkr
# 770     SBrkr
# 1333    SBrkr
# 131     SBrkr
# 872     SBrkr
# 1124    SBrkr
# 1397    SBrkr
# 88      SBrkr
# 331     SBrkr
# 1239    SBrkr
# 467     SBrkr
# 122     SBrkr
# 1045    SBrkr
# 1096    SBrkr
# 1131    SBrkr
# 1295    SBrkr
# 861     SBrkr
# 1127    SBrkr
# Name: Electrical, Length: 1168, dtype: object
# Id
# 255     TA
# 1067    TA
# 639     TA
# 800     Gd
# 381     Gd
# 304     TA
# 87      Gd
# 1386    Gd
# 266     Gd
# 794     Gd
# 1446    TA
# 809     TA
# 1100    TA
# 606     TA
# 702     TA
# 222     Gd
# 114     Gd
# 549     TA
# 1074    TA
# 175     TA
# 515     TA
# 1351    TA
# 1146    TA
# 966     Gd
# 937     Gd
# 286     Gd
# 1311    Ex
# 343     TA
# 1166    Gd
# 32      Gd
#         ..
# 748     Gd
# 253     Gd
# 22      Gd
# 1338    Fa
# 460     Gd
# 1185    TA
# 277     Gd
# 956     TA
# 1216    TA
# 386     Gd
# 806     Ex
# 1438    Ex
# 344     Ex
# 770     Ex
# 1333    TA
# 131     Gd
# 872     Gd
# 1124    TA
# 1397    TA
# 88      Gd
# 331     TA
# 1239    TA
# 467     TA
# 122     TA
# 1045    Gd
# 1096    Gd
# 1131    Gd
# 1295    TA
# 861     Gd
# 1127    Gd
# Name: KitchenQual, Length: 1168, dtype: object
# Id
# 255      Typ
# 1067     Typ
# 639      Typ
# 800      Typ
# 381      Typ
# 304      Typ
# 87       Typ
# 1386     Typ
# 266      Typ
# 794      Typ
# 1446     Typ
# 809      Typ
# 1100     Typ
# 606      Typ
# 702      Typ
# 222      Typ
# 114      Typ
# 549      Typ
# 1074     Typ
# 175     Min2
# 515      Typ
# 1351     Typ
# 1146     Typ
# 966      Typ
# 937      Typ
# 286      Typ
# 1311     Typ
# 343      Typ
# 1166     Typ
# 32       Typ
#         ...
# 748      Typ
# 253      Typ
# 22       Typ
# 1338     Typ
# 460      Typ
# 1185     Typ
# 277      Typ
# 956      Typ
# 1216     Typ
# 386      Typ
# 806      Typ
# 1438     Typ
# 344      Typ
# 770      Mod
# 1333     Typ
# 131      Typ
# 872      Typ
# 1124     Typ
# 1397    Min1
# 88       Typ
# 331      Typ
# 1239     Typ
# 467      Typ
# 122      Typ
# 1045     Typ
# 1096     Typ
# 1131    Min2
# 1295     Typ
# 861      Typ
# 1127     Typ
# Name: Functional, Length: 1168, dtype: object
# Id
# 255     NaN
# 1067     TA
# 639     NaN
# 800      TA
# 381      Gd
# 304     NaN
# 87       Gd
# 1386    NaN
# 266      TA
# 794     NaN
# 1446    NaN
# 809      Gd
# 1100     TA
# 606      Fa
# 702     NaN
# 222      TA
# 114      Gd
# 549     NaN
# 1074    NaN
# 175      TA
# 515     NaN
# 1351    NaN
# 1146     Gd
# 966      Gd
# 937     NaN
# 286     NaN
# 1311     TA
# 343     NaN
# 1166    NaN
# 32      NaN
#        ...
# 748      Gd
# 253     NaN
# 22       Gd
# 1338    NaN
# 460      TA
# 1185     TA
# 277     NaN
# 956     NaN
# 1216    NaN
# 386      TA
# 806     NaN
# 1438     Gd
# 344      Ex
# 770      Gd
# 1333     Gd
# 131      Gd
# 872     NaN
# 1124    NaN
# 1397     TA
# 88      NaN
# 331     NaN
# 1239    NaN
# 467      Po
# 122     NaN
# 1045     Gd
# 1096     Gd
# 1131     TA
# 1295    NaN
# 861      Gd
# 1127     TA
# Name: FireplaceQu, Length: 1168, dtype: object
# Id
# 255      Attchd
# 1067     Attchd
# 639         NaN
# 800      Detchd
# 381      Detchd
# 304      Attchd
# 87      BuiltIn
# 1386     Detchd
# 266      Attchd
# 794      Attchd
# 1446     Detchd
# 809      Attchd
# 1100     Attchd
# 606      Attchd
# 702      Attchd
# 222     BuiltIn
# 114     Basment
# 549      Detchd
# 1074     Attchd
# 175      Attchd
# 515      Detchd
# 1351     Detchd
# 1146     Detchd
# 966      Attchd
# 937      Attchd
# 286      Detchd
# 1311     Attchd
# 343      Detchd
# 1166     Attchd
# 32       Attchd
#          ...
# 748      Detchd
# 253      Attchd
# 22       Attchd
# 1338        NaN
# 460      Detchd
# 1185     2Types
# 277      Attchd
# 956      Attchd
# 1216     Detchd
# 386      Attchd
# 806      Attchd
# 1438     Attchd
# 344      Attchd
# 770     BuiltIn
# 1333     Detchd
# 131      Attchd
# 872      Attchd
# 1124        NaN
# 1397     Detchd
# 88       Detchd
# 331      Detchd
# 1239     Detchd
# 467      Attchd
# 122      Detchd
# 1045     Attchd
# 1096     Attchd
# 1131     Detchd
# 1295     Detchd
# 861      Detchd
# 1127     Attchd
# Name: GarageType, Length: 1168, dtype: object
# Id
# 255     RFn
# 1067    RFn
# 639     NaN
# 800     Unf
# 381     Unf
# 304     Unf
# 87      Fin
# 1386    Unf
# 266     Fin
# 794     Fin
# 1446    Unf
# 809     RFn
# 1100    RFn
# 606     Unf
# 702     Unf
# 222     RFn
# 114     Unf
# 549     RFn
# 1074    Fin
# 175     Fin
# 515     Unf
# 1351    Unf
# 1146    Unf
# 966     Fin
# 937     RFn
# 286     RFn
# 1311    Fin
# 343     Unf
# 1166    RFn
# 32      Unf
#        ...
# 748     Unf
# 253     RFn
# 22      Unf
# 1338    NaN
# 460     Unf
# 1185    RFn
# 277     Fin
# 956     Unf
# 1216    RFn
# 386     Fin
# 806     RFn
# 1438    Fin
# 344     RFn
# 770     Fin
# 1333    Unf
# 131     Fin
# 872     RFn
# 1124    NaN
# 1397    Unf
# 88      RFn
# 331     Unf
# 1239    Unf
# 467     Unf
# 122     Unf
# 1045    Fin
# 1096    RFn
# 1131    Unf
# 1295    Unf
# 861     Unf
# 1127    Fin
# Name: GarageFinish, Length: 1168, dtype: object
# Id
# 255      TA
# 1067     TA
# 639     NaN
# 800      TA
# 381      TA
# 304      TA
# 87       TA
# 1386     TA
# 266      TA
# 794      TA
# 1446     TA
# 809      TA
# 1100     TA
# 606      TA
# 702      TA
# 222      TA
# 114      TA
# 549      TA
# 1074     TA
# 175      TA
# 515      Po
# 1351     TA
# 1146     TA
# 966      TA
# 937      TA
# 286      TA
# 1311     TA
# 343      TA
# 1166     TA
# 32       TA
#        ...
# 748      TA
# 253      TA
# 22       TA
# 1338    NaN
# 460      TA
# 1185     TA
# 277      TA
# 956      TA
# 1216     TA
# 386      TA
# 806      TA
# 1438     TA
# 344      TA
# 770      TA
# 1333     Fa
# 131      TA
# 872      TA
# 1124    NaN
# 1397     TA
# 88       TA
# 331      TA
# 1239     TA
# 467      TA
# 122      TA
# 1045     TA
# 1096     TA
# 1131     TA
# 1295     TA
# 861      TA
# 1127     TA
# Name: GarageQual, Length: 1168, dtype: object
# Id
# 255      TA
# 1067     TA
# 639     NaN
# 800      TA
# 381      TA
# 304      TA
# 87       TA
# 1386     TA
# 266      TA
# 794      TA
# 1446     TA
# 809      TA
# 1100     TA
# 606      TA
# 702      TA
# 222      TA
# 114      TA
# 549      TA
# 1074     TA
# 175      TA
# 515      Po
# 1351     TA
# 1146     TA
# 966      TA
# 937      TA
# 286      TA
# 1311     TA
# 343      TA
# 1166     TA
# 32       TA
#        ...
# 748      TA
# 253      TA
# 22       TA
# 1338    NaN
# 460      TA
# 1185     TA
# 277      TA
# 956      TA
# 1216     TA
# 386      TA
# 806      TA
# 1438     TA
# 344      TA
# 770      TA
# 1333     Fa
# 131      TA
# 872      TA
# 1124    NaN
# 1397     TA
# 88       TA
# 331      TA
# 1239     TA
# 467      TA
# 122      TA
# 1045     TA
# 1096     TA
# 1131     TA
# 1295     TA
# 861      TA
# 1127     TA
# Name: GarageCond, Length: 1168, dtype: object
# Id
# 255     Y
# 1067    Y
# 639     P
# 800     Y
# 381     Y
# 304     Y
# 87      Y
# 1386    N
# 266     Y
# 794     Y
# 1446    Y
# 809     Y
# 1100    Y
# 606     Y
# 702     Y
# 222     Y
# 114     Y
# 549     Y
# 1074    Y
# 175     Y
# 515     Y
# 1351    Y
# 1146    Y
# 966     Y
# 937     Y
# 286     Y
# 1311    Y
# 343     Y
# 1166    Y
# 32      Y
#        ..
# 748     N
# 253     Y
# 22      N
# 1338    N
# 460     Y
# 1185    Y
# 277     Y
# 956     Y
# 1216    Y
# 386     Y
# 806     Y
# 1438    Y
# 344     Y
# 770     Y
# 1333    Y
# 131     Y
# 872     Y
# 1124    Y
# 1397    N
# 88      Y
# 331     Y
# 1239    Y
# 467     Y
# 122     P
# 1045    Y
# 1096    Y
# 1131    Y
# 1295    N
# 861     Y
# 1127    Y
# Name: PavedDrive, Length: 1168, dtype: object
# Id
# 255     NaN
# 1067    NaN
# 639     NaN
# 800     NaN
# 381     NaN
# 304     NaN
# 87      NaN
# 1386    NaN
# 266     NaN
# 794     NaN
# 1446    NaN
# 809     NaN
# 1100    NaN
# 606     NaN
# 702     NaN
# 222     NaN
# 114     NaN
# 549     NaN
# 1074    NaN
# 175     NaN
# 515     NaN
# 1351    NaN
# 1146    NaN
# 966     NaN
# 937     NaN
# 286     NaN
# 1311    NaN
# 343     NaN
# 1166    NaN
# 32      NaN
#        ...
# 748     NaN
# 253     NaN
# 22      NaN
# 1338    NaN
# 460     NaN
# 1185    NaN
# 277     NaN
# 956     NaN
# 1216    NaN
# 386     NaN
# 806     NaN
# 1438    NaN
# 344     NaN
# 770     NaN
# 1333    NaN
# 131     NaN
# 872     NaN
# 1124    NaN
# 1397    NaN
# 88      NaN
# 331     NaN
# 1239    NaN
# 467     NaN
# 122     NaN
# 1045    NaN
# 1096    NaN
# 1131    NaN
# 1295    NaN
# 861     NaN
# 1127    NaN
# Name: PoolQC, Length: 1168, dtype: object
# Id
# 255       NaN
# 1067      NaN
# 639     MnPrv
# 800     MnPrv
# 381       NaN
# 304      GdWo
# 87        NaN
# 1386    MnPrv
# 266     GdPrv
# 794       NaN
# 1446      NaN
# 809      GdWo
# 1100      NaN
# 606       NaN
# 702       NaN
# 222       NaN
# 114     MnPrv
# 549     MnPrv
# 1074    MnPrv
# 175       NaN
# 515     MnPrv
# 1351      NaN
# 1146      NaN
# 966       NaN
# 937       NaN
# 286       NaN
# 1311      NaN
# 343       NaN
# 1166      NaN
# 32      MnPrv
#         ...
# 748       NaN
# 253       NaN
# 22      GdPrv
# 1338      NaN
# 460       NaN
# 1185      NaN
# 277       NaN
# 956       NaN
# 1216    MnPrv
# 386       NaN
# 806       NaN
# 1438      NaN
# 344       NaN
# 770       NaN
# 1333      NaN
# 131     GdPrv
# 872       NaN
# 1124      NaN
# 1397      NaN
# 88        NaN
# 331       NaN
# 1239      NaN
# 467      GdWo
# 122     MnPrv
# 1045    MnPrv
# 1096      NaN
# 1131    MnPrv
# 1295      NaN
# 861     GdPrv
# 1127      NaN
# Name: Fence, Length: 1168, dtype: object
# Id
# 255     NaN
# 1067    NaN
# 639     NaN
# 800     NaN
# 381     NaN
# 304     NaN
# 87      NaN
# 1386    NaN
# 266     NaN
# 794     NaN
# 1446    NaN
# 809     NaN
# 1100    NaN
# 606     NaN
# 702     NaN
# 222     NaN
# 114     NaN
# 549     NaN
# 1074    NaN
# 175     NaN
# 515     NaN
# 1351    NaN
# 1146    NaN
# 966     NaN
# 937     NaN
# 286     NaN
# 1311    NaN
# 343     NaN
# 1166    NaN
# 32      NaN
#        ...
# 748     NaN
# 253     NaN
# 22      NaN
# 1338    NaN
# 460     NaN
# 1185    NaN
# 277     NaN
# 956     NaN
# 1216    NaN
# 386     NaN
# 806     NaN
# 1438    NaN
# 344     NaN
# 770     NaN
# 1333    NaN
# 131     NaN
# 872     NaN
# 1124    NaN
# 1397    NaN
# 88      NaN
# 331     NaN
# 1239    NaN
# 467     NaN
# 122     NaN
# 1045    NaN
# 1096    NaN
# 1131    NaN
# 1295    NaN
# 861     NaN
# 1127    NaN
# Name: MiscFeature, Length: 1168, dtype: object
# Id
# 255        WD
# 1067       WD
# 639        WD
# 800        WD
# 381        WD
# 304        WD
# 87         WD
# 1386       WD
# 266        WD
# 794       New
# 1446       WD
# 809        WD
# 1100      COD
# 606        WD
# 702       COD
# 222     ConLI
# 114       COD
# 549        WD
# 1074       WD
# 175        WD
# 515        WD
# 1351       WD
# 1146       WD
# 966       New
# 937        WD
# 286       New
# 1311       WD
# 343        WD
# 1166      New
# 32         WD
#         ...
# 748        WD
# 253        WD
# 22         WD
# 1338       WD
# 460        WD
# 1185       WD
# 277        WD
# 956        WD
# 1216       WD
# 386        WD
# 806       New
# 1438      New
# 344        WD
# 770        WD
# 1333       WD
# 131        WD
# 872        WD
# 1124       WD
# 1397       WD
# 88        New
# 331        WD
# 1239       WD
# 467        WD
# 122        WD
# 1045       WD
# 1096       WD
# 1131       WD
# 1295       WD
# 861        WD
# 1127       WD
# Name: SaleType, Length: 1168, dtype: object
# Id
# 255      Normal
# 1067     Normal
# 639      Normal
# 800      Normal
# 381      Normal
# 304     Abnorml
# 87       Normal
# 1386     Normal
# 266      Normal
# 794     Partial
# 1446     Normal
# 809      Normal
# 1100    Abnorml
# 606      Normal
# 702      Normal
# 222      Normal
# 114     Abnorml
# 549      Normal
# 1074     Normal
# 175      Normal
# 515      Normal
# 1351     Normal
# 1146     Family
# 966     Partial
# 937      Normal
# 286     Partial
# 1311     Normal
# 343      Normal
# 1166    Partial
# 32       Normal
#          ...
# 748      Normal
# 253      Normal
# 22       Normal
# 1338     Normal
# 460      Normal
# 1185     Normal
# 277      Normal
# 956      Normal
# 1216     Normal
# 386      Normal
# 806     Partial
# 1438    Partial
# 344      Normal
# 770      Normal
# 1333     Normal
# 131      Normal
# 872      Normal
# 1124     Normal
# 1397     Normal
# 88      Partial
# 331      Normal
# 1239    Abnorml
# 467      Normal
# 122      Normal
# 1045     Normal
# 1096     Normal
# 1131     Normal
# 1295     Normal
# 861      Normal
# 1127     Normal
# Name: SaleCondition, Length: 1168, dtype: object

# %% [markdown]
# ### Dealing with missing data and categorical data

# %% [markdown]
# #### Impulation
